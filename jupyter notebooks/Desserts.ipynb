# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('menu.csv')

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# ..         ...  ...            ...                            ...
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# ..             ...                            ...     ...      ...
# 255              1                              4      64       12
# 256              1                              5      85       15
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# ..                       ...                   ...
# 255                       40                     8
# 256                       50                    10
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [260 rows x 24 columns]

# %%
for column in df.columns:
    df = df.rename(columns={column : column.replace("(% Daily Value)", "DV")} )
for column in df.columns:
    df = df.rename(columns={column : column.replace(" ", "_")})
    
if 'Serving_Size' in df.columns:
    df['Serving_Size_g'] = None
    for i,value in enumerate(df['Serving_Size']):
        if (value.find('fl') < 0 and value.find('ml') < 0):
            value = (value[value.find("(")+1:value.find(" g")])
            df['Serving_Size_g'][i] = np.float64(value)
            df['Serving_Size'][i] = None
        else:
            if (value.find(' fl') > 0):
                df['Serving_Size'][i] = (np.float64(value[0:value.find(' fl')]) * 29.57)
            elif (value.find(' ml') > 0):
                df['Serving_Size'][i] = np.float64(value[value.find(' ml')-3:value.find(' ml')])

    df = df.rename(columns={"Serving_Size": "Serving_Size_ml"})

    if (df.columns.tolist()[3] != "Serving_Size_g"):
        cols = df.columns.tolist()
        cols = cols[:3] + cols[-1:] + cols[-22:-1]
        df = df[cols]

    df['Serving_Size_g'] = np.float64(df['Serving_Size_g'])
    df['Serving_Size_ml'] = np.float64(df['Serving_Size_ml'])

display(df.dtypes)
# Out:
# Category              object
# Item                  object
# Serving_Size_ml      float64
# Serving_Size_g       float64
# Calories               int64
# Calories_from_Fat      int64
# Total_Fat            float64
# Total_Fat_DV           int64
# Saturated_Fat        float64
# Saturated_Fat_DV       int64
# Trans_Fat            float64
# Cholesterol            int64
# Cholesterol_DV         int64
# Sodium                 int64
# Sodium_DV              int64
# Carbohydrates          int64
# Carbohydrates_DV       int64
# Dietary_Fiber          int64
# Dietary_Fiber_DV       int64
# Sugars                 int64
# Protein                int64
# Vitamin_A_DV           int64
# Vitamin_C_DV           int64
# Calcium_DV             int64
# Iron_DV                int64
# dtype: object

# %%
df = df[df['Category'].isin(['Desserts'])]

df.shape
# Out:
# (7, 25)

# %%
df
# Out:
#      Category                   Item  Serving_Size_ml  Serving_Size_g  \
# 103  Desserts        Baked Apple Pie              NaN            77.0
# 104  Desserts  Chocolate Chip Cookie              NaN            33.0
# 105  Desserts  Oatmeal Raisin Cookie              NaN            33.0
# 106  Desserts    Kids Ice Cream Cone              NaN            29.0
# 107  Desserts       Hot Fudge Sundae              NaN           179.0
# 108  Desserts     Hot Caramel Sundae              NaN           182.0
# 109  Desserts      Strawberry Sundae              NaN           178.0
#
#      Calories  Calories_from_Fat  Total_Fat  Total_Fat_DV  Saturated_Fat  \
# 103       250                110       13.0            19            7.0
# 104       160                 70        8.0            12            3.5
# 105       150                 50        6.0             9            2.5
# 106        45                 10        1.5             2            1.0
# 107       330                 80        9.0            14            7.0
# 108       340                 70        8.0            12            5.0
# 109       280                 60        6.0            10            4.0
#
#      Saturated_Fat_DV  ...  Carbohydrates  Carbohydrates_DV  Dietary_Fiber  \
# 103                35  ...             32                11              4
# 104                19  ...             21                 7              1
# 105                13  ...             22                 7              1
# 106                 4  ...              7                 2              0
# 107                34  ...             53                18              1
# 108                24  ...             60                20              0
# 109                20  ...             49                16              0
#
#      Dietary_Fiber_DV  Sugars  Protein  Vitamin_A_DV  Vitamin_C_DV  \
# 103                15      13        2             4            25
# 104                 3      15        2             2             0
# 105                 3      13        2             2             0
# 106                 0       6        1             2             0
# 107                 3      48        8             8             0
# 108                 0      43        7            10             0
# 109                 0      45        6             8             4
#
#      Calcium_DV  Iron_DV
# 103           2        6
# 104           2        8
# 105           2        6
# 106           4        0
# 107          25        8
# 108          25        0
# 109          20        0
#
# [7 rows x 25 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Serving_Size_g')
plt.title('Boxplot of Serving size in Desserts Category')
plt.xlabel('Serving Size')
plt.show()

# %%
max_calories_index = df['Calories'].idxmax()

item_with_most_calories = df.loc[max_calories_index, 'Item']
max_calories = df.loc[max_calories_index, 'Calories']

print(f"The item with the most calories in the Desserts category is '{item_with_most_calories}' with {max_calories} calories.")
# Out:
# The item with the most calories in the Desserts category is 'Hot Caramel Sundae' with 340 calories.

# %%
max_calories_from_fat_index = df['Calories_from_Fat'].idxmax()

item_with_most_calories_from_fat = df.loc[max_calories_from_fat_index, 'Item']
max_calories_from_fat = df.loc[max_calories_from_fat_index, 'Calories_from_Fat']

print(f"The item with the most calories from fat in the Desserts category is '{item_with_most_calories_from_fat}' with {max_calories_from_fat} calories.")
# Out:
# The item with the most calories from fat in the Desserts category is 'Baked Apple Pie' with 110 calories.

# %%
max_fat_index = df['Total_Fat'].idxmax()

item_with_most_fat = df.loc[max_fat_index, 'Item']
max_fat = df.loc[max_fat_index, 'Total_Fat']

print(f"The item with the most fat in the Desserts category is '{item_with_most_fat}' with {max_fat} fats.")
# Out:
# The item with the most fat in the Desserts category is 'Baked Apple Pie' with 13.0 fats.

# %%
max_Saturated_Fat_index = df['Saturated_Fat'].idxmax()

item_with_most_Saturated_fat = df.loc[max_Saturated_Fat_index, 'Item']
max_saturated_fat = df.loc[max_Saturated_Fat_index, 'Saturated_Fat']

print(f"The item with the most saturated fat in the Desserts category is '{item_with_most_Saturated_fat}' with {max_saturated_fat} fats.")
# Out:
# The item with the most saturated fat in the Desserts category is 'Baked Apple Pie' with 7.0 fats.

# %%
max_Cholesterol_index = df['Cholesterol'].idxmax()

item_with_most_Cholesterol = df.loc[max_Cholesterol_index, 'Item']
max_Cholesterol = df.loc[max_Cholesterol_index, 'Cholesterol']

print(f"The item with the most Cholestrol in the Desserts category is '{item_with_most_Cholesterol}' with {max_Cholesterol} ")
# Out:
# The item with the most Cholestrol in the Desserts category is 'Hot Caramel Sundae' with 30

# %%
max_Sodium_index = df['Sodium'].idxmax()

item_with_most_Sodium = df.loc[max_Sodium_index, 'Item']
max_Sodium = df.loc[max_Sodium_index, 'Sodium']

print(f"The item with the most Sodium in the Desserts category is '{item_with_most_Sodium}' with {max_Sodium} ")
# Out:
# The item with the most Sodium in the Desserts category is 'Baked Apple Pie' with 170

# %%
max_Carbohydrates_index = df['Carbohydrates'].idxmax()

item_with_most_Carbohydrates = df.loc[max_Carbohydrates_index, 'Item']
max_Carbohydrates = df.loc[max_Carbohydrates_index, 'Carbohydrates']

print(f"The item with the most Carbohydrates in the Desserts category is '{item_with_most_Carbohydrates}' with {max_Carbohydrates} ")
# Out:
# The item with the most Carbohydrates in the Desserts category is 'Hot Caramel Sundae' with 60

# %%
max_Sugars_index = df['Sugars'].idxmax()

item_with_most_Sugars = df.loc[max_Sugars_index, 'Item']
max_Sugars = df.loc[max_Sugars_index, 'Sugars']

print(f"The item with the most Sugars in the Desserts category is '{item_with_most_Sugars}' with {max_Sugars} ")
# Out:
# The item with the most Sugars in the Desserts category is 'Hot Fudge Sundae' with 48

# %%
max_Protein_index = df['Protein'].idxmax()

item_with_most_Protein = df.loc[max_Protein_index, 'Item']
max_Protein = df.loc[max_Protein_index, 'Protein']

print(f"The item with the most Protein in the Desserts category is '{item_with_most_Protein}' with {max_Protein} ")
# Out:
# The item with the most Protein in the Desserts category is 'Hot Fudge Sundae' with 8

# %%
max_Dietary_Fiber_index = df['Dietary_Fiber'].idxmax()

item_with_most_Dietary_Fiber = df.loc[max_Dietary_Fiber_index, 'Item']
max_Dietary_Fiber = df.loc[max_Dietary_Fiber_index, 'Dietary_Fiber']

print(f"The item with the most Dietary Fiber in the Desserts category is '{item_with_most_Dietary_Fiber}' with {max_Dietary_Fiber} ")
# Out:
# The item with the most Dietary Fiber in the Desserts category is 'Baked Apple Pie' with 4
